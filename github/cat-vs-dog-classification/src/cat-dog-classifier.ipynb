# %% [markdown]
# Cat Dog Classification
# ===

# %%
import tensorflow as tf
import os
import re
import numpy as np
import zipfile
import matplotlib.pyplot as plt

from tensorflow.contrib import learn
from tensorflow.contrib.learn.python.learn.estimators import model_fn
from tensorflow.contrib.learn import RunConfig as run_config

slim = tf.contrib.slim

# %% [markdown]
# ### Utility function
# Image reader, Input pipeline, etc.

# %%
CAT = 0
DOG = 1
IS_LOW_MEMORY_MODE = True

cwd = os.getcwd()
np.random.seed(2124)

# %%
def prepare_file():
  file_list = ['train', 'test']
  valid = True

  for i in range(len(file_list)):
    filename = file_list[i] + '.zip'
    dest_filename = os.path.join(cwd, 'data', filename)

    if not os.path.exists(dest_filename):
      print('Please download ' + filename + ' and put on src/data folder')
      url = "https://www.kaggle.com/c/dogs-vs-cats-redux-kernels-edition/download/"
      print(url + filename)
      valid = False
      continue
    
    images_path = os.path.join(cwd, 'data', file_list[i])

    zip = zipfile.ZipFile(dest_filename)
    if not os.path.exists(images_path):
        print('Extracting...')
        zip.extractall(os.path.join(cwd, 'data'))
      
  return valid

def read_image_label_list(folder_dir):
    dir_list = os.listdir(os.path.join(cwd, folder_dir))
    
    filenames = []
    labels = []
    
    for i, d in enumerate(dir_list):
        if re.search("train", folder_dir):
            if re.search("cat", d):
                labels.append(CAT)
            else:
                labels.append(DOG)
        else:
            labels.append(-1)
        filenames.append(os.path.join(cwd, folder_dir, d))
    
    return filenames, labels

def read_images_from_disk(input_queue):
    filename = input_queue[0]
    label = input_queue[1]
    
    file_contents = tf.read_file(filename)
    image = tf.image.decode_image(file_contents, channels=3)
    image.set_shape([None, None, 3])
    
    return image, label

def gen_input_fn(image_list, label_list, batch_size, shuffle):
    
    def input_fn():
        images = tf.convert_to_tensor(image_list, dtype=tf.string)
        labels = tf.convert_to_tensor(label_list, dtype=tf.int32)

        input_queue = tf.train.slice_input_producer(
            [images, labels],
            capacity=batch_size * 5,
            shuffle=shuffle,
            name="file_input_queue"
        )

        image, label = read_images_from_disk(input_queue)

        image = tf.image.resize_images(image, (224, 224), tf.image.ResizeMethod.NEAREST_NEIGHBOR)

        image_batch, label_batch = tf.train.batch(
            [image, label],
            batch_size=batch_size,
            num_threads=1,
            name="batch_queue",
            capacity=batch_size * 10,
            allow_smaller_final_batch = False
        )
        
        return (
            tf.identity(image_batch, name="features"), 
            tf.identity(label_batch, name="label")
        )

    return input_fn

def train_valid_input_fn(data_dir, train_batch_size, valid_batch_size=None):
    img, labels = read_image_label_list(data_dir)
    img = np.array(img)
    labels = np.array(labels)
    data_size = img.shape[0]

    print("Data size: " + str(data_size))
    split = int(0.7 * data_size)

    random_seq = np.random.permutation(data_size)

    img = img[random_seq]
    labels = labels[random_seq]
    
    if valid_batch_size == None:
        valid_batch_size = train_batch_size

    return (
        gen_input_fn(img[0:split], labels[0:split], train_batch_size, shuffle = True),
        gen_input_fn(img[split:], labels[split:], valid_batch_size, shuffle = False)
    )

def test_input_fn(data_dir, batch_size):
    image_list, label_list = read_image_label_list(data_dir)
    return gen_input_fn(image_list, label_list, batch_size, shuffle = False), image_list

# %% [markdown]
# ### Preview Data
# Check correctness of data

# %%
if prepare_file():
    print "Files are ready \o/"
# Out:
# Files are ready \o/

# %%
def plot_img(data, label=None):
    plt.ion()
    plt.figure()
    plt.imshow(data)
    if label is not None:
        plt.title(label)

def preview_img():
    
    img_preview = tf.Graph()
    
    with img_preview.as_default():
        tensor_train, _ = train_valid_input_fn('data/train', 5)
        result = tf.tuple(tensor_train())
        
    with tf.Session(graph=img_preview) as sess:
        sess.run(tf.global_variables_initializer())
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(coord=coord)

        images, labels = sess.run(result)
        for i in range(len(images)):
            plot_img(images[i], str(labels[i]))

        coord.request_stop()
        coord.join(threads)

        sess.close()

preview_img()
# Out:
# Data size: 25000

# %% [markdown]
# ### Define Model
# Create a model for using in Estimator

# %%
def catdog_model(inputs, is_training):
    with tf.variable_scope('vgg_19', values=[inputs]):
        with slim.arg_scope(
            [slim.conv2d, slim.fully_connected],
            activation_fn=tf.nn.relu,
            weights_initializer=tf.truncated_normal_initializer(0.0, 0.01),
            weights_regularizer=slim.l2_regularizer(0.0005)):
            
            net = inputs
        
            if IS_LOW_MEMORY_MODE == False:
                net = slim.repeat(net, 2, slim.conv2d, 64, [3, 3], scope='conv1')
                net = slim.max_pool2d(net, [2, 2], scope='pool1')

                net = slim.repeat(net, 2, slim.conv2d, 128, [3, 3], scope='conv2')
                net = slim.max_pool2d(net, [2, 2], scope='pool2')

                net = slim.repeat(net, 4, slim.conv2d, 256, [3, 3], scope='conv3')
                net = slim.max_pool2d(net, [2, 2], scope='pool3')
                net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv4')
                net = slim.max_pool2d(net, [2, 2], scope='pool4')
                net = slim.repeat(net, 4, slim.conv2d, 512, [3, 3], scope='conv5')
                net = slim.max_pool2d(net, [2, 2], scope='pool5')

                net = tf.reshape(net, [-1, 7 * 7 * 512])

                net = slim.fully_connected(net, 2048, scope='fc6')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout6')

                net = slim.fully_connected(net, 2048, scope='fc7')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout7')

                net = slim.fully_connected(net, 2, activation_fn=None, scope='fc8')
                
            else:
                # Model for my Mac T_T
                net = tf.image.resize_images(net, (72, 72), tf.image.ResizeMethod.NEAREST_NEIGHBOR)
                
                net = slim.repeat(net, 1, slim.conv2d, 64, [3, 3], scope='conv1')
                net = slim.max_pool2d(net, [2, 2], scope='pool1')
                
                net = slim.repeat(net, 1, slim.conv2d, 128, [3, 3], scope='conv2')
                net = slim.max_pool2d(net, [2, 2], scope='pool2')
                
                net = slim.repeat(net, 2, slim.conv2d, 256, [3, 3], scope='conv3')
                net = slim.max_pool2d(net, [2, 2], scope='pool3')
                
                net = tf.reshape(net, [-1, 9 * 9 * 256])
                
                net = slim.fully_connected(net, 1024, scope='fc4')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout4')

                net = slim.fully_connected(net, 1024, scope='fc5')
                net = slim.dropout(net, 0.5, is_training=is_training, scope='dropout5')

                net = slim.fully_connected(net, 2, activation_fn=None, scope='fc6')
            
            return net

# %%
def catdog_model_fn(features, labels, mode, params):
    
    is_training = False
    if mode == learn.ModeKeys.TRAIN:
        is_training = True
        
    output = catdog_model(features, is_training)
    
    loss = None
    train_op = None
    eval_metric_ops = None
    
    if mode != learn.ModeKeys.INFER:
        onehot_labels = tf.one_hot(
            tf.cast(labels, tf.int32), 
            depth = 2
        )
        loss = tf.losses.softmax_cross_entropy(
            onehot_labels = onehot_labels,
            logits = output 
        )
        
    if mode == learn.ModeKeys.TRAIN:
        train_op = tf.contrib.layers.optimize_loss(
            loss = loss,
            global_step = tf.contrib.framework.get_global_step(),
            learning_rate = params['learning_rate'],
            optimizer = "Adam"
        )
    
    classes_predictions = tf.argmax(output, axis = 1, name = "classes_tensor")
    
    if mode != learn.ModeKeys.INFER:
        accuracy_metric = tf.identity(
            tf.metrics.accuracy(labels, classes_predictions)[1],
            name = "accuracy_tensor"
        )
        eval_metric_ops = {
            "accuracy": accuracy_metric,
            "log_loss": tf.losses.log_loss(
                labels,
                classes_predictions,
                reduction = tf.losses.Reduction.MEAN
            )
        }
        predictions = {
            'classes': classes_predictions,
            'accuracy': accuracy_metric
        }
    else:
        predictions = {
            'classes': classes_predictions
        }
    
    return model_fn.ModelFnOps(
        mode = mode,
        predictions = predictions,
        loss = loss,
        train_op = train_op,
        eval_metric_ops = eval_metric_ops
    )

# %% [markdown]
# Define model classifier

# %%
def feature_engineering_fn(features, labels):
    features = tf.to_float(features)
    features = tf.map_fn(tf.image.per_image_standardization, features)

    return features, labels

tf.logging.set_verbosity(tf.logging.ERROR)

# Change `_model` to `model`, if you'd like to use trained model
model_path = '_model/catdog_low' if IS_LOW_MEMORY_MODE else '_model/catdog'
classifier = learn.Estimator(
    model_fn = catdog_model_fn, 
    model_dir = model_path,
    config = run_config(
        save_summary_steps = 10,
        keep_checkpoint_max = 3,
        save_checkpoints_steps = 100
    ),
    feature_engineering_fn = feature_engineering_fn,
    params = {
        'learning_rate': 0.001
    }
)

train_input_fn, validate_input_fn = train_valid_input_fn('data/train', 32, 64)

logging_hook = tf.train.LoggingTensorHook(
    tensors = {
        'accuracy': 'accuracy_tensor'
    }, 
    every_n_iter = 3
)

validation_monitor = tf.contrib.learn.monitors.ValidationMonitor(
    input_fn = validate_input_fn,
    eval_steps = 20,
    every_n_steps = 50,
    name = 'Validatation'
)
# Out:
# Data size: 25000

# %% [markdown]
# Let its trainnnn !!!

# %%
tf.logging.set_verbosity(tf.logging.INFO)

classifier.fit(
    input_fn = train_input_fn,
    steps = 100,
    monitors = [logging_hook, validation_monitor]
)
# Out:
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Restoring parameters from _model/catdog_low/model.ckpt-19806
# INFO:tensorflow:Saving checkpoints for 19807 into _model/catdog_low/model.ckpt.
# INFO:tensorflow:loss = 0.092406, step = 19807
# INFO:tensorflow:accuracy = 1.0
# INFO:tensorflow:Starting evaluation at 2017-07-15-05:25:19
# INFO:tensorflow:Restoring parameters from _model/catdog_low/model.ckpt-19807
# INFO:tensorflow:Evaluation [1/20]
# INFO:tensorflow:Evaluation [2/20]
# INFO:tensorflow:Evaluation [3/20]
# INFO:tensorflow:Evaluation [4/20]
# INFO:tensorflow:Evaluation [5/20]
# INFO:tensorflow:Evaluation [6/20]
# INFO:tensorflow:Evaluation [7/20]
# INFO:tensorflow:Evaluation [8/20]
# INFO:tensorflow:Evaluation [9/20]
# INFO:tensorflow:Evaluation [10/20]
# INFO:tensorflow:Evaluation [11/20]
# INFO:tensorflow:Evaluation [12/20]
# INFO:tensorflow:Evaluation [13/20]
# INFO:tensorflow:Evaluation [14/20]
# INFO:tensorflow:Evaluation [15/20]
# INFO:tensorflow:Evaluation [16/20]
# INFO:tensorflow:Evaluation [17/20]
# INFO:tensorflow:Evaluation [18/20]
# INFO:tensorflow:Evaluation [19/20]
# INFO:tensorflow:Evaluation [20/20]
# INFO:tensorflow:Finished evaluation at 2017-07-15-05:26:25
# INFO:tensorflow:Saving dict for global step 19807: accuracy = 0.953125, global_step = 19807, log_loss = 0.755536, loss = 0.134687
# INFO:tensorflow:Validation (step 19807): log_loss = 0.755536, loss = 0.134687, global_step = 19807, accuracy = 0.953125
# INFO:tensorflow:accuracy = 1.0 (85.145 sec)
# INFO:tensorflow:accuracy = 0.96875 (13.300 sec)
# INFO:tensorflow:accuracy = 0.96875 (13.407 sec)
# INFO:tensorflow:accuracy = 0.9625 (13.888 sec)
# INFO:tensorflow:accuracy = 0.963542 (12.881 sec)
# INFO:tensorflow:accuracy = 0.955357 (12.927 sec)
# INFO:tensorflow:accuracy = 0.960938 (10.239 sec)
# INFO:tensorflow:accuracy = 0.961806 (11.068 sec)
# INFO:tensorflow:accuracy = 0.959375 (13.660 sec)
# INFO:tensorflow:accuracy = 0.951705 (14.383 sec)
# INFO:tensorflow:accuracy = 0.947917 (12.745 sec)
# INFO:tensorflow:accuracy = 0.947115 (12.309 sec)
# INFO:tensorflow:accuracy = 0.950893 (11.700 sec)
# INFO:tensorflow:accuracy = 0.947917 (10.173 sec)
# INFO:tensorflow:accuracy = 0.947266 (10.237 sec)
# INFO:tensorflow:accuracy = 0.946691 (10.117 sec)
# INFO:tensorflow:accuracy = 0.947917 (10.162 sec)
# INFO:tensorflow:accuracy = 0.947368 (10.109 sec)
# INFO:tensorflow:accuracy = 0.948438 (10.176 sec)
# INFO:tensorflow:accuracy = 0.949405 (10.056 sec)
# INFO:tensorflow:accuracy = 0.951705 (10.055 sec)
# INFO:tensorflow:accuracy = 0.94837 (10.827 sec)
# INFO:tensorflow:accuracy = 0.947917 (10.181 sec)
# INFO:tensorflow:accuracy = 0.9475 (9.998 sec)
# INFO:tensorflow:accuracy = 0.947115 (10.002 sec)
# INFO:tensorflow:accuracy = 0.947917 (9.954 sec)
# INFO:tensorflow:accuracy = 0.948661 (10.382 sec)
# INFO:tensorflow:accuracy = 0.945043 (10.000 sec)
# INFO:tensorflow:accuracy = 0.94375 (9.922 sec)
# INFO:tensorflow:accuracy = 0.943548 (10.198 sec)
# INFO:tensorflow:accuracy = 0.945312 (10.103 sec)
# INFO:tensorflow:accuracy = 0.946023 (9.921 sec)
# INFO:tensorflow:accuracy = 0.945772 (9.935 sec)
# INFO:tensorflow:Saving checkpoints for 19906 into _model/catdog_low/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.261087.
# Estimator(params={'learning_rate': 0.001})

# %%
classifier.evaluate(
    input_fn = validate_input_fn,
    steps = 75
)
# Out:
# INFO:tensorflow:Starting evaluation at 2017-07-15-05:32:42
# INFO:tensorflow:Restoring parameters from _model/catdog_low/model.ckpt-19906
# INFO:tensorflow:Evaluation [1/75]
# INFO:tensorflow:Evaluation [2/75]
# INFO:tensorflow:Evaluation [3/75]
# INFO:tensorflow:Evaluation [4/75]
# INFO:tensorflow:Evaluation [5/75]
# INFO:tensorflow:Evaluation [6/75]
# INFO:tensorflow:Evaluation [7/75]
# INFO:tensorflow:Evaluation [8/75]
# INFO:tensorflow:Evaluation [9/75]
# INFO:tensorflow:Evaluation [10/75]
# INFO:tensorflow:Evaluation [11/75]
# INFO:tensorflow:Evaluation [12/75]
# INFO:tensorflow:Evaluation [13/75]
# INFO:tensorflow:Evaluation [14/75]
# INFO:tensorflow:Evaluation [15/75]
# INFO:tensorflow:Evaluation [16/75]
# INFO:tensorflow:Evaluation [17/75]
# INFO:tensorflow:Evaluation [18/75]
# INFO:tensorflow:Evaluation [19/75]
# INFO:tensorflow:Evaluation [20/75]
# INFO:tensorflow:Evaluation [21/75]
# INFO:tensorflow:Evaluation [22/75]
# INFO:tensorflow:Evaluation [23/75]
# INFO:tensorflow:Evaluation [24/75]
# INFO:tensorflow:Evaluation [25/75]
# INFO:tensorflow:Evaluation [26/75]
# INFO:tensorflow:Evaluation [27/75]
# INFO:tensorflow:Evaluation [28/75]
# INFO:tensorflow:Evaluation [29/75]
# INFO:tensorflow:Evaluation [30/75]
# INFO:tensorflow:Evaluation [31/75]
# INFO:tensorflow:Evaluation [32/75]
# INFO:tensorflow:Evaluation [33/75]
# INFO:tensorflow:Evaluation [34/75]
# INFO:tensorflow:Evaluation [35/75]
# INFO:tensorflow:Evaluation [36/75]
# INFO:tensorflow:Evaluation [37/75]
# INFO:tensorflow:Evaluation [38/75]
# INFO:tensorflow:Evaluation [39/75]
# INFO:tensorflow:Evaluation [40/75]
# INFO:tensorflow:Evaluation [41/75]
# INFO:tensorflow:Evaluation [42/75]
# INFO:tensorflow:Evaluation [43/75]
# INFO:tensorflow:Evaluation [44/75]
# INFO:tensorflow:Evaluation [45/75]
# INFO:tensorflow:Evaluation [46/75]
# INFO:tensorflow:Evaluation [47/75]
# INFO:tensorflow:Evaluation [48/75]
# INFO:tensorflow:Evaluation [49/75]
# INFO:tensorflow:Evaluation [50/75]
# INFO:tensorflow:Evaluation [51/75]
# INFO:tensorflow:Evaluation [52/75]
# INFO:tensorflow:Evaluation [53/75]
# INFO:tensorflow:Evaluation [54/75]
# INFO:tensorflow:Evaluation [55/75]
# INFO:tensorflow:Evaluation [56/75]
# INFO:tensorflow:Evaluation [57/75]
# INFO:tensorflow:Evaluation [58/75]
# INFO:tensorflow:Evaluation [59/75]
# INFO:tensorflow:Evaluation [60/75]
# INFO:tensorflow:Evaluation [61/75]
# INFO:tensorflow:Evaluation [62/75]
# INFO:tensorflow:Evaluation [63/75]
# INFO:tensorflow:Evaluation [64/75]
# INFO:tensorflow:Evaluation [65/75]
# INFO:tensorflow:Evaluation [66/75]
# INFO:tensorflow:Evaluation [67/75]
# INFO:tensorflow:Evaluation [68/75]
# INFO:tensorflow:Evaluation [69/75]
# INFO:tensorflow:Evaluation [70/75]
# INFO:tensorflow:Evaluation [71/75]
# INFO:tensorflow:Evaluation [72/75]
# INFO:tensorflow:Evaluation [73/75]
# INFO:tensorflow:Evaluation [74/75]
# INFO:tensorflow:Evaluation [75/75]
# INFO:tensorflow:Finished evaluation at 2017-07-15-05:35:37
# INFO:tensorflow:Saving dict for global step 19906: accuracy = 0.96875, global_step = 19906, log_loss = 0.50369, loss = 0.119607
# {'accuracy': 0.96875,
#  'global_step': 19906,
#  'log_loss': 0.50369042,
#  'loss': 0.1196074}

# %% [markdown]
# Let's predicttt !!!

# %%
test_fn, image_test_list = test_input_fn('data/test', 32)
test_n = len(image_test_list)

print("Test size: %d" % test_n)

result_file = open(os.path.join(cwd, 'result/result.txt'), 'w+')
result_file.write('id,label\n')

predictions = classifier.predict(input_fn = test_fn, as_iterable=True)
for i, p in enumerate(predictions):
    if i >= test_n:
        break
        
    id = image_test_list[i].split("/")[-1]
    id = id.split(".")[0]

    if i % 100 == 0:
        print("Predict %d %s: %s" % (i, image_test_list[i], p["classes"]))

    result_file.write("%s,%s\n" % (id, p["classes"]))

result_file.flush()
result_file.close()
print('Finish!!')
# Out:
# Test size: 12500
# INFO:tensorflow:Restoring parameters from _model/catdog_low/model.ckpt-19906
# Predict 0 /notebooks/data/test/1.jpg: 1
# Predict 100 /notebooks/data/test/10088.jpg: 0
# Predict 200 /notebooks/data/test/10178.jpg: 1
# Predict 300 /notebooks/data/test/10268.jpg: 1
# Predict 400 /notebooks/data/test/10358.jpg: 0
# Predict 500 /notebooks/data/test/10448.jpg: 1
# Predict 600 /notebooks/data/test/10538.jpg: 0
# Predict 700 /notebooks/data/test/10628.jpg: 0
# Predict 800 /notebooks/data/test/10718.jpg: 0
# Predict 900 /notebooks/data/test/10808.jpg: 1
# Predict 1000 /notebooks/data/test/10899.jpg: 0
# Predict 1100 /notebooks/data/test/10989.jpg: 0
# Predict 1200 /notebooks/data/test/11078.jpg: 0
# Predict 1300 /notebooks/data/test/11168.jpg: 0
# Predict 1400 /notebooks/data/test/11258.jpg: 1
# Predict 1500 /notebooks/data/test/11348.jpg: 0
# Predict 1600 /notebooks/data/test/11438.jpg: 1
# Predict 1700 /notebooks/data/test/11528.jpg: 0
# Predict 1800 /notebooks/data/test/11618.jpg: 0
# Predict 1900 /notebooks/data/test/11708.jpg: 0
# Predict 2000 /notebooks/data/test/11799.jpg: 0
# Predict 2100 /notebooks/data/test/11889.jpg: 0
# Predict 2200 /notebooks/data/test/11979.jpg: 1
# Predict 2300 /notebooks/data/test/12068.jpg: 0
# Predict 2400 /notebooks/data/test/12158.jpg: 1
# Predict 2500 /notebooks/data/test/12248.jpg: 1
# Predict 2600 /notebooks/data/test/12338.jpg: 0
# Predict 2700 /notebooks/data/test/12428.jpg: 0
# Predict 2800 /notebooks/data/test/1268.jpg: 1
# Predict 2900 /notebooks/data/test/1358.jpg: 1
# Predict 3000 /notebooks/data/test/1448.jpg: 1
# Predict 3100 /notebooks/data/test/1538.jpg: 1
# Predict 3200 /notebooks/data/test/1628.jpg: 1
# Predict 3300 /notebooks/data/test/1718.jpg: 0
# Predict 3400 /notebooks/data/test/1808.jpg: 0
# Predict 3500 /notebooks/data/test/1899.jpg: 0
# Predict 3600 /notebooks/data/test/1989.jpg: 1
# Predict 3700 /notebooks/data/test/2078.jpg: 1
# Predict 3800 /notebooks/data/test/2168.jpg: 0
# Predict 3900 /notebooks/data/test/2258.jpg: 1
# Predict 4000 /notebooks/data/test/2348.jpg: 0
# Predict 4100 /notebooks/data/test/2438.jpg: 1
# Predict 4200 /notebooks/data/test/2528.jpg: 0
# Predict 4300 /notebooks/data/test/2618.jpg: 0
# Predict 4400 /notebooks/data/test/2708.jpg: 0
# Predict 4500 /notebooks/data/test/2799.jpg: 0
# Predict 4600 /notebooks/data/test/2889.jpg: 1
# Predict 4700 /notebooks/data/test/2979.jpg: 0
# Predict 4800 /notebooks/data/test/3068.jpg: 1
# Predict 4900 /notebooks/data/test/3158.jpg: 0
# Predict 5000 /notebooks/data/test/3248.jpg: 1
# Predict 5100 /notebooks/data/test/3338.jpg: 1
# Predict 5200 /notebooks/data/test/3428.jpg: 0
# Predict 5300 /notebooks/data/test/3518.jpg: 0
# Predict 5400 /notebooks/data/test/3608.jpg: 1
# Predict 5500 /notebooks/data/test/3699.jpg: 0
# Predict 5600 /notebooks/data/test/3789.jpg: 1
# Predict 5700 /notebooks/data/test/3879.jpg: 1
# Predict 5800 /notebooks/data/test/3969.jpg: 1
# Predict 5900 /notebooks/data/test/4058.jpg: 0
# Predict 6000 /notebooks/data/test/4148.jpg: 0
# Predict 6100 /notebooks/data/test/4238.jpg: 1
# Predict 6200 /notebooks/data/test/4328.jpg: 0
# Predict 6300 /notebooks/data/test/4418.jpg: 0
# Predict 6400 /notebooks/data/test/4508.jpg: 0
# Predict 6500 /notebooks/data/test/4599.jpg: 1
# Predict 6600 /notebooks/data/test/4689.jpg: 1
# Predict 6700 /notebooks/data/test/4779.jpg: 0
# Predict 6800 /notebooks/data/test/4869.jpg: 0
# Predict 6900 /notebooks/data/test/4959.jpg: 1
# Predict 7000 /notebooks/data/test/5048.jpg: 1
# Predict 7100 /notebooks/data/test/5138.jpg: 0
# Predict 7200 /notebooks/data/test/5228.jpg: 1
# Predict 7300 /notebooks/data/test/5318.jpg: 1
# Predict 7400 /notebooks/data/test/5408.jpg: 0
# Predict 7500 /notebooks/data/test/5499.jpg: 0
# Predict 7600 /notebooks/data/test/5589.jpg: 0
# Predict 7700 /notebooks/data/test/5679.jpg: 0
# Predict 7800 /notebooks/data/test/5769.jpg: 0
# Predict 7900 /notebooks/data/test/5859.jpg: 0
# Predict 8000 /notebooks/data/test/5949.jpg: 0
# Predict 8100 /notebooks/data/test/6038.jpg: 1
# Predict 8200 /notebooks/data/test/6128.jpg: 1
# Predict 8300 /notebooks/data/test/6218.jpg: 0
# Predict 8400 /notebooks/data/test/6308.jpg: 1
# Predict 8500 /notebooks/data/test/6399.jpg: 1
# Predict 8600 /notebooks/data/test/6489.jpg: 1
# Predict 8700 /notebooks/data/test/6579.jpg: 1
# Predict 8800 /notebooks/data/test/6669.jpg: 0
# Predict 8900 /notebooks/data/test/6759.jpg: 1
# Predict 9000 /notebooks/data/test/6849.jpg: 1
# Predict 9100 /notebooks/data/test/6939.jpg: 0
# Predict 9200 /notebooks/data/test/7028.jpg: 0
# Predict 9300 /notebooks/data/test/7118.jpg: 1
# Predict 9400 /notebooks/data/test/7208.jpg: 0
# Predict 9500 /notebooks/data/test/7299.jpg: 0
# Predict 9600 /notebooks/data/test/7389.jpg: 0
# Predict 9700 /notebooks/data/test/7479.jpg: 1
# Predict 9800 /notebooks/data/test/7569.jpg: 0
# Predict 9900 /notebooks/data/test/7659.jpg: 1
# Predict 10000 /notebooks/data/test/7749.jpg: 0
# Predict 10100 /notebooks/data/test/7839.jpg: 1
# Predict 10200 /notebooks/data/test/7929.jpg: 1
# Predict 10300 /notebooks/data/test/8018.jpg: 1
# Predict 10400 /notebooks/data/test/8108.jpg: 1
# Predict 10500 /notebooks/data/test/8199.jpg: 1
# Predict 10600 /notebooks/data/test/8289.jpg: 0
# Predict 10700 /notebooks/data/test/8379.jpg: 1
# Predict 10800 /notebooks/data/test/8469.jpg: 0
# Predict 10900 /notebooks/data/test/8559.jpg: 1
# Predict 11000 /notebooks/data/test/8649.jpg: 0
# Predict 11100 /notebooks/data/test/8739.jpg: 1
# Predict 11200 /notebooks/data/test/8829.jpg: 1
# Predict 11300 /notebooks/data/test/8919.jpg: 1
# Predict 11400 /notebooks/data/test/9008.jpg: 0
# Predict 11500 /notebooks/data/test/9099.jpg: 1
# Predict 11600 /notebooks/data/test/9189.jpg: 1
# Predict 11700 /notebooks/data/test/9279.jpg: 1
# Predict 11800 /notebooks/data/test/9369.jpg: 1
# Predict 11900 /notebooks/data/test/9459.jpg: 0
# Predict 12000 /notebooks/data/test/9549.jpg: 1
# Predict 12100 /notebooks/data/test/9639.jpg: 1
# Predict 12200 /notebooks/data/test/9729.jpg: 0
# Predict 12300 /notebooks/data/test/9819.jpg: 1
# Predict 12400 /notebooks/data/test/9909.jpg: 0
# Finish!!
